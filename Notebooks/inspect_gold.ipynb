# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("nyc-taxi-inspect-bronze")
    .master("local[*]")
    .config("spark.driver.memory", "6g")
    .config("spark.sql.shuffle.partitions", "16")
    .getOrCreate()
)
spark.sparkContext.setLogLevel("WARN")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/04 16:00:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/02/04 16:00:11 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/02/04 16:00:11 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
gold = spark.read.parquet("../data/processed/gold/nyc_taxi/daily_metrics/yellow_tripdata_2016-01")
gold.show(30, truncate=False)
(gold.count(), len(gold.columns))
# Out:
# +----------+-------------+----------------+-----------------+---------------------+-----------+
# |trip_count|total_revenue|avg_total_amount|avg_trip_distance|avg_trip_duration_min|pickup_date|
# +----------+-------------+----------------+-----------------+---------------------+-----------+
# |340167    |5281122.91   |15.53           |2.91             |12.76                |2016-01-11 |
# |77220     |1144138.86   |14.82           |2.8              |13.83                |2016-01-23 |
# |310216    |4695777.61   |15.14           |3.083            |12.03                |2016-01-02 |
# |402831    |5750217.29   |14.27           |2.714            |11.88                |2016-01-09 |
# |349077    |5272469.64   |15.1            |3.095            |11.5                 |2016-01-10 |
# |158433    |2376689.96   |15.0            |2.954            |12.5                 |2016-01-24 |
# |392408    |5924814.24   |15.1            |2.707            |12.83                |2016-01-13 |
# |345978    |5214747.25   |15.07           |2.801            |12.6                 |2016-01-06 |
# |376214    |5623654.66   |14.95           |2.976            |11.86                |2016-01-17 |
# |393674    |6195045.54   |15.74           |2.869            |13.39                |2016-01-14 |
# |379168    |6035328.28   |15.92           |2.867            |13.79                |2016-01-20 |
# |279490    |5181539.84   |18.54           |3.319            |17.68                |2016-01-25 |
# |362270    |5532227.59   |15.27           |2.817            |12.83                |2016-01-07 |
# |432009    |6469267.41   |14.97           |2.697            |13.0                 |2016-01-30 |
# |338757    |5053345.81   |14.92           |3.014            |11.34                |2016-01-18 |
# |398381    |6377282.39   |16.01           |2.966            |13.83                |2016-01-15 |
# |325063    |5845530.12   |17.98           |3.06             |17.53                |2016-01-26 |
# |410923    |6565044.02   |15.98           |2.813            |14.39                |2016-01-29 |
# |313681    |4802342.32   |15.31           |30.554           |11.92                |2016-01-04 |
# |389233    |5885258.86   |15.12           |2.758            |12.88                |2016-01-08 |
# |382052    |6030812.25   |15.79           |2.83             |13.73                |2016-01-19 |
# |364793    |5519386.64   |15.13           |2.755            |12.69                |2016-01-12 |
# |340699    |5127143.54   |15.05           |7.776            |12.38                |2016-01-05 |
# |408717    |6013708.1    |14.71           |2.833            |12.23                |2016-01-16 |
# |356560    |5978713.4    |16.77           |2.865            |15.79                |2016-01-27 |
# |341729    |5321203.72   |15.57           |3.293            |11.89                |2016-01-01 |
# |396735    |6376257.94   |16.07           |8.996            |14.31                |2016-01-21 |
# |380599    |6290512.89   |16.53           |19.504           |15.14                |2016-01-28 |
# |300170    |4808753.59   |16.02           |3.429            |11.91                |2016-01-03 |
# |358437    |5624468.51   |15.69           |3.14             |12.67                |2016-01-31 |
# +----------+-------------+----------------+-----------------+---------------------+-----------+
# only showing top 30 rows
# (31, 6)
